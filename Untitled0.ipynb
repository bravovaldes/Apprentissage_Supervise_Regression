# %% [markdown]
# <a href="https://colab.research.google.com/github/bravovaldes/Apprentissage_Supervise_Regression/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.impute import KNNImputer

# %%
california = fetch_california_housing()

# Créer un DataFrame à partir des données
df_california = pd.DataFrame(california.data, columns=california.feature_names)

# Ajouter la variable cible au DataFrame
df_california['MedHouseVal'] = california.target

df_california.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
df_california.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
df_california.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
df_california.isnull().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %%
df_california.hist(figsize=(20, 15), bins=30)
plt.tight_layout()
plt.show()

# %%
sns.boxplot(x=df_california['MedHouseVal'])
plt.show()

# %%
#Definitions des variables Expliquatives

x = df_california.drop('MedHouseVal', axis=1)    # Toutes les colonnes sauf 'MedHouseVal'
y = df_california['MedHouseVal']    # Colonne cible

#Diviser les donnees en ensemblesd'entrainement et de test

X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2, random_state=42)


# Afficher la taille des ensembles
print(f"Taille des données d'entraînement : {X_train.shape}")
print(f"Taille des données de test : {X_test.shape}")
# Out:
# Taille des données d'entraînement : (16512, 8)
# Taille des données de test : (4128, 8)

# %%
model = LinearRegression()

model.fit(X_train, Y_train)

# Afficher les coefficients du modèle
print("Coefficients :", model.coef_)
print("Intercept :", model.intercept_)
# Out:
# Coefficients : [ 4.48674910e-01  9.72425752e-03 -1.23323343e-01  7.83144907e-01
#  -2.02962058e-06 -3.52631849e-03 -4.19792487e-01 -4.33708065e-01]
# Intercept : -37.02327770606409

# %%
Y_pred = model.predict(X_test)

mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)
rmse = np.sqrt(mse)

# Afficher les résultats
print(f"Mean Squared Error (MSE) : {mse:.2f}")
print(f"Root Mean Squared Error (RMSE) : {rmse:.2f}")
print(f"Coefficient de Détermination (R²) : {r2:.2f}")
# Out:
# Mean Squared Error (MSE) : 0.56
# Root Mean Squared Error (RMSE) : 0.75
# Coefficient de Détermination (R²) : 0.58

# %%
# Foret aleatoire

# Initialisons le modele de Foret Aleatoire

rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Entrainer le modele

rf_model.fit(X_train, Y_train)

# Faire des predictions sur l'ensemble de test

Y_pred_rf = rf_model.predict(X_test)

# Évaluer le modèle
mse_rf = mean_squared_error(Y_test, Y_pred)
rmse_rf = np.sqrt(mse_rf)
r2_rf = r2_score(Y_test, Y_pred)

print(f"Random Forest - MSE : {mse_rf:.2f}")
print(f"Random Forest - RMSE : {rmse_rf:.2f}")
print(f"Random Forest - R² : {r2_rf:.2f}")

#Visualtion des valeurs reeles vs predictions

plt.scatter(Y_test, Y_pred, alpha=0.5, label='Régression Linéaire')
plt.scatter(Y_test, Y_pred_rf, alpha=0.5, color='red', label='Forêt Aléatoire')
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], 'k--', lw=2)
plt.xlabel('Valeurs Réelles')
plt.ylabel('Prédictions')
plt.legend()
plt.title('Comparaison des Prédictions')
plt.show()
# Out:
# Random Forest - MSE : 0.56
# Random Forest - RMSE : 0.75
# Random Forest - R² : 0.58

# %%
# prompt: code pour choisir le meilleur model en fonction de ce code
# Y_pred = model.predict(X_test)
# mse = mean_squared_error(Y_test, Y_pred)
# r2 = r2_score(Y_test, Y_pred)
# rmse = np.sqrt(mse)
# # Afficher les résultats
# print(f"Mean Squared Error (MSE) : {mse:.2f}")
# print(f"Root Mean Squared Error (RMSE) : {rmse:.2f}")
# print(f"Coefficient de Détermination (R²) : {r2:.2f}")
# # Foret aleatoire
# # Initialisons le modele de Foret Aleatoire
# rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
# # Entrainer le modele
# rf_model.fit(X_train, Y_train)
# # Faire des predictions sur l'ensemble de test
# Y_pred_rf = rf_model.predict(X_test)
# # Évaluer le modèle
# mse_rf = mean_squared_error(Y_test, Y_pred)
# rmse_rf = np.sqrt(mse_rf)
# r2_rf = r2_score(Y_test, Y_pred)
# print(f"Random Forest - MSE : {mse_rf:.2f}")
# print(f"Random Forest - RMSE : {rmse_rf:.2f}")
# print(f"Random Forest - R² : {r2_rf:.2f}")
# #Visualtion des valeurs reeles vs predictions
# plt.scatter(Y_test, Y_pred, alpha=0.5, label='Régression Linéaire')
# plt.scatter(Y_test, Y_pred_rf, alpha=0.5, color='red', label='Forêt Aléatoire')
# plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], 'k--', lw=2)
# plt.xlabel('Valeurs Réelles')
# plt.ylabel('Prédictions')
# plt.legend()
# plt.title('Comparaison des Prédictions')
# plt.show()

from sklearn.datasets import fetch_california_housing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.impute import KNNImputer

# ... (previous code remains the same)

# Evaluate and compare models
models = {
    "Linear Regression": model,
    "Random Forest": rf_model
}

results = {}
for name, model in models.items():
    Y_pred = model.predict(X_test)
    mse = mean_squared_error(Y_test, Y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(Y_test, Y_pred)
    results[name] = {"MSE": mse, "RMSE": rmse, "R^2": r2}
    print(f"{name} - MSE : {mse:.2f}")
    print(f"{name} - RMSE : {rmse:.2f}")
    print(f"{name} - R² : {r2:.2f}")

# Determine the best model based on a chosen metric (e.g., R^2)
best_model_name = max(results, key=lambda k: results[k]["R^2"])
best_model = models[best_model_name]

print(f"\nBest Model: {best_model_name}")
print(f"R^2 score of best model: {results[best_model_name]['R^2']:.2f}")

# Visualize predictions of the best model
plt.scatter(Y_test, best_model.predict(X_test), alpha=0.5)
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], 'k--', lw=2)
plt.xlabel('Valeurs Réelles')
plt.ylabel('Prédictions')
plt.title(f'Prédictions du meilleur modèle: {best_model_name}')
plt.show()
# Out:
# Linear Regression - MSE : 0.56
# Linear Regression - RMSE : 0.75
# Linear Regression - R² : 0.58
# Random Forest - MSE : 0.26
# Random Forest - RMSE : 0.51
# Random Forest - R² : 0.80
#
# Best Model: Random Forest
# R^2 score of best model: 0.80

# %%
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt

# %%
# Charger les données "penguins"
data = sns.load_dataset("penguins")

# Afficher les premières lignes du jeu de données
data.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
# Supprimer les lignes avec des valeurs manquantes
data = data.dropna()

# Conversion de la colonne "species" (cible) en variables numériques
data['species'] = data['species'].astype('category').cat.codes

# Conversion des variables catégoriques restantes
data['island'] = data['island'].astype('category').cat.codes
data['sex'] = data['sex'].astype('category').cat.codes

# %%
# Définir les caractéristiques (X) et la cible (y)
X = data.drop('species', axis=1)
y = data['species']

# Diviser les données en ensembles d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Normalisation des données
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Créer et entraîner le modèle
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# Prédictions sur l'ensemble de test
y_pred = model.predict(X_test)

# %%
# Afficher le rapport de classification
print("Rapport de classification:")
print(classification_report(y_test, y_pred))

# Matrice de confusion
conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='g')
plt.title("Matrice de confusion")
plt.xlabel("Prédictions")
plt.ylabel("Vérité terrain")
plt.show()
# Out:
# Rapport de classification:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        48
#            1       1.00      0.94      0.97        18
#            2       1.00      1.00      1.00        34
#
#     accuracy                           0.99       100
#    macro avg       0.99      0.98      0.99       100
# weighted avg       0.99      0.99      0.99       100

# %%
# Importance des caractéristiques
feature_importances = pd.Series(model.feature_importances_, index=data.drop('species', axis=1).columns)
feature_importances.sort_values(ascending=False).plot(kind='bar')
plt.title("Importance des caractéristiques")
plt.show()
